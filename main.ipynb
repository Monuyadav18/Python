# %% [markdown]
# <a href="https://colab.research.google.com/github/Monuyadav18/Python/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Namaste! We are learning Python here...")
# Out:
# Namaste! We are learning Python here...
